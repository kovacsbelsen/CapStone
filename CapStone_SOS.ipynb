# %%
#!pip install -U -r ./yolov5/requirements.txt

# %%
import cv2
import sys
import os
import torch
from IPython.display import Image  # for displaying images
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
torch.cuda.is_available()
torch.cuda.get_device_name(0)
# Out:
# torch 1.8.1 _CudaDeviceProperties(name='NVIDIA GeForce GTX 1060 with Max-Q Design', major=6, minor=1, total_memory=6144MB, multi_processor_count=10)
# 'NVIDIA GeForce GTX 1060 with Max-Q Design'

# %%
cd 1_Capstone_SOS
# Out:
# C:\Users\kovac\Github\1_Capstone_SOS

# %%
cd CapStone
# Out:
# C:\Users\kovac\Github\1_Capstone_SOS\CapStone

# %%
cd yolov5
# Out:
# [WinError 2] A rendszer nem találja a megadott fájlt: 'yolov5'
# C:\Users\kovac\Github\CapStone

# %%
cd ..
# Out:
# C:\Users\kovac\Github

# %%
#!python ./models/export.py --weights best.pt --img 416 --batch 1
# Out:
# Namespace(batch_size=1, device='cpu', dynamic=False, half=False, img_size=[416, 416], inplace=False, simplify=False, train=False, weights='best.pt')
#
# PyTorch: starting from best.pt (14.8 MB)
#
# TorchScript: starting export with torch 1.8.1...
# TorchScript: export success, saved as best.torchscript.pt (29.1 MB)
# ONNX: starting export with onnx 1.9.0...
# ONNX: export success, saved as best.onnx (29.1 MB)
# CoreML: export failure: No module named 'coremltools'
#
# Export complete (6.56s). Visualize with https://github.com/lutzroeder/netron.
# YOLOv5  2021-5-9 torch 1.8.1 CPU
#
# Fusing layers...
# Model Summary: 232 layers, 7251912 parameters, 0 gradients
# ...

# %%
# !python detect.py --source 0 --weights personhelmet.pt --conf 0.55
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.55, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='0', update=False, view_img=False, weights=['personhelmet.pt'])
# 1/1: 0...  success (640x480 at 30.00 FPS).
#
# 0: 480x640 2 heads, 1 person, Done. (1.293s)
# 0: 480x640 2 heads, 1 person, Done. (0.031s)
# 0: 480x640 2 heads, 1 person, Done. (0.026s)
# 0: 480x640 2 heads, 1 person, Done. (0.023s)
# 0: 480x640 2 heads, 1 person, Done. (0.025s)
# 0: 480x640 2 heads, 1 person, Done. (0.027s)
# 0: 480x640 2 heads, 1 person, Done. (0.049s)
# 0: 480x640 2 heads, 1 person, Done. (0.058s)
# 0: 480x640 1 head, 1 person, Done. (0.024s)
# 0: 480x640 1 head, 1 person, Done. (0.028s)
# 0: 480x640 1 head, 1 person, Done. (0.025s)
# 0: 480x640 2 heads, 1 person, Done. (0.026s)
# ...

# %%
# !python detectgate.py --source 0 --weights personhelmet.pt --conf 0.55
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.55, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='0', update=False, view_img=False, weights=['personhelmet.pt'])
# 1/1: 0...  success (640x480 at 30.00 FPS).
#
# 0
# helmetcounter 1
# 2
# helmetcounter 1
# 0: 480x640 2 heads, 1 person, Done. (1.238s)
# 0
# helmetcounter 1
# 2
# helmetcounter 1
# 0: 480x640 2 heads, 1 person, Done. (0.041s)
# 0
# helmetcounter 1
# 2
# helmetcounter 1
# 0: 480x640 2 heads, 1 person, Done. (0.026s)
# 0
# helmetcounter 1
# 2
# helmetcounter 1
# 0: 480x640 2 heads, 1 person, Done. (0.031s)
# 0
# helmetcounter 1
# 2
# helmetcounter 1
# 0: 480x640 2 heads, 1 person, Done. (0.028s)
# 0
# helmetcounter 1
# 2
# helmetcounter 1
# 0: 480x640 2 heads, 1 person, Done. (0.090s)
# 0
# helmetcounter 1
# 2
# ...

# %%
# !python track.py --source 0 --weights personhelmet.pt --conf-thres 0.55 --save-vid
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[0, 1], conf_thres=0.55, config_deepsort='deep_sort_pytorch/configs/deep_sort.yaml', device='', fourcc='mp4v', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, save_vid=True, source='0', view_vid=True, weights='personhelmet.pt')
# 1/1: 0...  success (640x480 at 30.00 FPS).
#
# 0
# 0: 480x640 1 heads, Done. (1.062s)
# 0
# 0: 480x640 1 heads, Done. (0.030s)
# 1
# 0: 480x640 1 heads, Done. (0.030s)
# 1
# 0: 480x640 1 heads, Done. (0.027s)
# 1
# 0: 480x640 1 heads, Done. (0.028s)
# 1
# C:\Users\kovac\Github\1_Capstone_SOS\CapStone\deep_sort_pytorch\utils\parser.py:24: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.update(yaml.load(fo.read()))
# 0: 480x640 1 heads, Done. (0.026s)
# 1
# 0: 480x640 1 heads, Done. (0.027s)
# 1
# 0: 480x640 1 heads, Done. (0.026s)
# 1
# ...

# %%
# !python track_movement.py --source 0 --weights personhelmet.pt --classes 2  --save-vid
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=[2], conf_thres=0.4, config_deepsort='deep_sort_pytorch/configs/deep_sort.yaml', device='', fourcc='mp4v', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, save_vid=True, source='0', view_vid=True, weights='personhelmet.pt')
# 1/1: 0...  success (640x480 at 30.00 FPS).
#
# 0
# 0: 480x640 1 persons, Done. (1.090s)
# 0
# 2
# 0: 480x640 1 persons, Done. (0.024s)
# 0
# 3
# 3
# 0: 480x640 1 persons, Done. (0.022s)
# 0
# 4
# C:\Users\kovac\Github\1_Capstone_SOS\CapStone\deep_sort_pytorch\utils\parser.py:24: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   self.update(yaml.load(fo.read()))
# 4
# 4
# 0: 480x640 1 persons, Done. (0.023s)
# 0
# 5
# 5
# 5
# 5
# 0: 480x640 1 persons, Done. (0.025s)
# 0
# 6
# 6
# 6
# 6
# 6
# 0: 480x640 1 persons, Done. (0.025s)
# 0
# 7
# 7
# 7
# 7
# 7
# 7
# ...

# %%
# cap at 0.6 each helmet, count helmet predictions for each frame, if count <= 20 show

# %%
#detect humans, try to detect the helmet on the human, count the detections

# %%
#https://github.com/mikel-brostrom/Yolov5_DeepSort_Pytorch
